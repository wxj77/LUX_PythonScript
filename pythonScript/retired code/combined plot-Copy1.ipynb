# %%
import sys
import os
import functools
import scipy
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pylab as pylab
from matplotlib.colors import LogNorm
import pickle
import math
import subprocess
import warnings


sys.path.insert(2, "/global/projecta/projectdirs/lux/data")
sys.path.insert(0,'/project/projectdirs/lux/Tools/LUXcode/Trunk/DataAnalysis/Python/' )
sys.path.insert(0,'/project/projectdirs/lux/Tools/LUXcode/Trunk/DataAnalysis/Python/aLib' )
import __init__ as S
import dp as dp

pylab.rcParams["figure.figsize"]=15,8
filedir = "/project/projectdirs/lux/users/weiji/band/"

# %%
b1509_10=np.load(filedir+"201509explogband.npy")
b1509_11=np.load(filedir+"201509simlogband.npy")
b1509_20=np.load(filedir+"201509expband.npy")
b1509_21=np.load(filedir+"201509simband.npy")
b1409_10=np.load(filedir+"201502explogband.npy")
b1409_11=np.load(filedir+"201502simlogband.npy")
b1409_20=np.load(filedir+"201502expband.npy")
b1409_21=np.load(filedir+"201502simband.npy")

# %%
375/75
# Out:
# 5

# %%
#comparision plot 
plt.figure(12)
plt.errorbar(b1509_10[2],b1509_10[0],b1509_10[1],lw=2, color="k",label="201509 exp")
plt.errorbar(b1509_11[2],b1509_11[0],b1509_11[1],lw=2, color="b",label="201509 sim")
plt.errorbar(b1409_10[2],b1409_10[0],b1409_10[1],lw=2, color="r",label="201502 exp")
plt.errorbar(b1409_11[2],b1409_11[0],b1409_11[1],lw=2, color="c",label="201502 sim")
plt.legend(loc=4,fontsize=35)
plt.xlim(1.0,2.3)
plt.ylim(3.0,4.)
plt.xlabel("Log10 S1", fontsize=18)
plt.ylabel("Log10 S2", fontsize=18)
plt.title("", fontsize=20)
#comparision plot 
plt.figure(22)
plt.errorbar(b1509_20[2],b1509_20[0],b1509_20[1],lw=2, color="k",label="201509 exp")
plt.errorbar(b1509_21[2],b1509_21[0],b1509_21[1],lw=2, color="b",label="201509 sim")
plt.errorbar(b1409_20[2],b1409_20[0],b1409_20[1],lw=2, color="r",label="201502 exp")
plt.errorbar(b1409_21[2],b1409_21[0],b1409_21[1],lw=2, color="c",label="201502 sim")
plt.legend(loc=0,fontsize=35)
plt.xlim(0,100.)
plt.ylim(1.5,4.)
plt.xlabel("S1", fontsize=18)
plt.ylabel("Log10 (S2/S1)", fontsize=18)
plt.title("", fontsize=20)

# %%
b1509_150=np.load(filedir+"201509explightyield.npy")
b1509_151=np.load(filedir+"201509simlightyield.npy")
b1409_150=np.load(filedir+"201502explightyield.npy")
b1409_151=np.load(filedir+"201502simlightyield.npy")

# %%
ax0.set_x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-59a7910efcad> in <module>()
# ----> 1 ax0.set_x
#
# NameError: name 'ax0' is not defined

# %%
#comparision plot 
plt.figure(12)
fig, (ax0, ax1) = plt.subplots(nrows=2)
ax0.errorbar(b1509_10[2],b1509_10[0],b1509_10[1],lw=2, color="k",label="201509 exp")
ax0.errorbar(b1509_11[2],b1509_11[0],b1509_11[1],lw=2, color="c",label="201509 sim")
#ax0.errorbar(b1409_10[2],b1409_10[0],b1409_10[1],lw=2, color="r",label="201502 exp")
#ax0.errorbar(b1409_11[2],b1409_11[0],b1409_11[1],lw=2, color="b",label="201409 sim")
ax0.legend(loc=4,fontsize=15)
ax0.set_xlim(1.0,2.1)
ax0.set_ylim(3.2,4.)
#ax0.xlabel("Log10 S1", fontsize=18)
ax0.set_ylabel("Log10 S2", fontsize=15)
ax0.set_title("Tritium Band Comparision",fontsize=15)
b11_inds = np.in1d(b1509_11[2],b1509_10[2])
b10_inds = np.in1d(b1509_10[2],b1509_11[2])
ax1.plot(b1509_11[2][b11_inds],b1509_11[0][b11_inds]-b1509_10[0][b10_inds],"ko",lw=2,label="201509")
b11_inds = np.in1d(b1409_11[2],b1409_10[2])
b10_inds = np.in1d(b1409_10[2],b1409_11[2])
ax1.plot(b1409_11[2][b11_inds],b1409_11[0][b11_inds]-b1409_10[0][b10_inds],"ro",lw=2,label="201502")
ax1.set_xlim(1.0,2.1)
ax1.set_ylim(-0.05,0.05)
ax1.set_ylabel("Log10 S2_Sim - Log10 S2_Exp", fontsize=15)
ax1.legend(loc=4,fontsize=15)
ax1.set_xlabel("Log10 S1", fontsize=15)

# %%
plt.figure(22)
fig, (ax0, ax1) = plt.subplots(nrows=2)
ax0.errorbar(b1509_20[2],b1509_20[0],b1509_20[1],lw=2, color="k",label="201509 exp")
ax0.errorbar(b1509_21[2],b1509_21[0],b1509_21[1],lw=2, color="c",label="201509 sim")
#ax0.errorbar(b1409_10[2],b1409_10[0],b1409_10[1],lw=2, color="r",label="201409")
#plt.errorbar(b1409_11[2],b1409_11[0],b1409_11[1],lw=2, color="c",label="201409 sim")
ax0.legend(loc=1,fontsize=15)
ax0.set_xlim(0,100)
ax0.set_ylim(1.5,3.5)
#ax0.xlabel("Log10 S1", fontsize=18)
ax0.set_ylabel("Log10 S2/S1", fontsize=15)
ax0.set_title("Tritium Band Comparision",fontsize=15)
b21_inds = np.in1d(b1509_21[2],b1509_20[2])
b20_inds = np.in1d(b1509_20[2],b1509_21[2])
ax1.plot(b1509_21[2][b21_inds],b1509_21[0][b21_inds]-b1509_20[0][b20_inds],"ko",lw=2,label="201509")
b21_inds = np.in1d(b1409_21[2],b1409_20[2])
b20_inds = np.in1d(b1409_20[2],b1409_21[2])
ax1.plot(b1409_21[2][b21_inds],b1409_21[0][b21_inds]-b1409_20[0][b20_inds],"ro",lw=2,label="201502")
ax1.set_xlim(0,100)
ax1.set_ylim(-0.05,0.05)
ax1.set_ylabel("Log10 (S2/S1)_Sim - Log10 (S2/S1)_Exp", fontsize=15)
ax1.legend(loc=4,fontsize=15)
ax1.set_xlabel("S1", fontsize=15)

# %%
LY = np.load("LY.npy")
LinE = np.load("LinE.npy")*100.
LY
# Out:
# array([ 5.16889122,  4.92107319,  4.79033401,  4.70002479,  4.64135474,
#         4.59535667,  4.54665768,  4.50840367,  4.47566659,  4.44458164,
#         4.41817785,  4.39478233,  4.35858629,  4.34623762,  4.32285931,
#         4.30343982,  4.28440289,  4.26658046,  4.25299102,  4.23223726,
#         4.22229085,  4.2035957 ,  4.19473629,  4.17640247,  4.16251894,
#         4.15531097,  4.13971976,  4.12739641,  4.11976895,  4.10542324,
#         4.10044777,  4.0890163 ,  4.0753466 ,  4.06666278,  4.05637309,
#         4.05386793,  4.03267071,  4.02856554,  4.02150042,  4.00915127,
#         4.00143706,  3.99923031,  3.99174058,  3.98053182,  3.98094146,
#         3.96958168,  3.96157811,  3.94928103,  3.94611213,  3.9379677 ,
#         3.93779806,  3.92914462,  3.92470003,  3.91487178,  3.91395244,
#         3.90090861,  3.89709848,  3.89618962,  3.88705932,  3.88887619,
#         3.86552797,  3.87145953,  3.8658626 ,  3.86294195,  3.8584013 ,
# ...

# %%
LinE
# Out:
# array([     0.,   1000.,   2000.,   3000.,   4000.,   5000.,   6000.,
#          7000.,   8000.,   9000.,  10000.,  11000.,  12000.,  13000.,
#         14000.,  15000.,  16000.,  17000.,  18000.,  19000.,  20000.,
#         21000.,  22000.,  23000.,  24000.,  25000.,  26000.,  27000.,
#         28000.,  29000.,  30000.,  31000.,  32000.,  33000.,  34000.,
#         35000.,  36000.,  37000.,  38000.,  39000.,  40000.,  41000.,
#         42000.,  43000.,  44000.,  45000.,  46000.,  47000.,  48000.,
#         49000.,  50000.,  51000.,  52000.,  53000.,  54000.,  55000.,
#         56000.,  57000.,  58000.,  59000.,  60000.,  61000.,  62000.,
#         63000.,  64000.,  65000.,  66000.,  67000.,  68000.,  69000.,
#         70000.,  71000.,  72000.,  73000.,  74000.,  75000.,  76000.,
#         77000.,  78000.,  79000.,  80000.,  81000.,  82000.,  83000.,
#         84000.,  85000.,  86000.,  87000.,  88000.,  89000.,  90000.,
# ...

# %%
bandfits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e0b956a535c6> in <module>()
# ----> 1 bandfits
#
# NameError: name 'bandfits' is not defined

# %%
ax0.errorbar(b1509_150[2],b1509_150[0],b1509_150[1],lw=2, color="k",label="201509 exp")
ax0.errorbar(b1509_151[2],b1509_151[0],b1509_151[1],lw=2, color="c",label="201509 sim")
ax0.errorbar(b1409_150[2],b1409_150[0],b1409_150[1],lw=2, color="k",label="201502 exp")
ax0.errorbar(b1409_151[2],b1409_151[0],b1409_151[1],lw=2, color="c",label="201502 sim")
#ax0.errorbar(b1409_10[2],b1409_10[0],b1409_10[1],lw=2, color="r",label="201409")
#ax0.errorbar(b1409_11[2],b1409_11[0],b1409_11[1],lw=2, color="c",label="201409 sim")
ax0.legend(loc=1,fontsize=15)
ax0.set_xlim(0,70000)
ax0.set_ylim(3.5,4.8)
#ax0.set_ylim()
#ax0.xlabel("Log10 S1", fontsize=18)
ax0.set_ylabel("S1/Energy", fontsize=15)
ax0.set_title("Light Yield vs Electric Field Comparision",fontsize=15)
b151_inds = np.in1d(b1509_151[2],b1509_150[2])
b150_inds = np.in1d(b1509_150[2],b1509_151[2])
ax1.plot(b1509_151[2][b151_inds],b1509_151[0][b151_inds]-b1509_150[0][b150_inds],"ko",lw=2,label="201509")
b151_inds = np.in1d(b1409_151[2],b1409_150[2])
b150_inds = np.in1d(b1409_150[2],b1409_151[2])
ax1.plot(b1409_151[2][b151_inds],b1409_151[0][b151_inds]-b1409_150[0][b150_inds],"ro",lw=2,label="201502")
ax1.set_xlim(0,70000)
ax1.set_ylim(-0.25,0.5)
ax1.set_ylabel("(S1/Energy)_Sim - (S1/Energy)_Exp", fontsize=15)
ax1.legend(loc=4,fontsize=15)
ax1.set_xlabel("E field (V/m)", fontsize=15)

# %%
bandfits=np.load("LYgaussian.npy")
plt.figure(153)
fig, (ax0, ax1) = plt.subplots(nrows=2)
#ax0.plot(LinE, LY,lw=4, color="m",label="LibNEST average bins")
ax0.plot(bandfits[2]*100.,bandfits[0],lw=4, color="g",label="LibNEST gaussian fit bins")
ax0.plot(b1509_150[2],b1509_150[0],lw=2, color="k",label="201509 exp")
ax0.plot(b1509_151[2],b1509_151[0],lw=2, color="c",label="201509 sim")
ax0.plot(b1409_150[2],b1409_150[0],lw=2, color="k",label="201502 exp")
ax0.plot(b1409_151[2],b1409_151[0],lw=2, color="c",label="201502 sim")
#ax0.errorbar(b1409_10[2],b1409_10[0],b1409_10[1],lw=2, color="r",label="201409")
#ax0.errorbar(b1409_11[2],b1409_11[0],b1409_11[1],lw=2, color="c",label="201409 sim")
ax0.legend(loc=1,fontsize=15)
ax0.set_xlim(0,70000)
ax0.set_ylim(3.5,4.8)
#ax0.set_ylim()
#ax0.xlabel("Log10 S1", fontsize=18)
ax0.set_ylabel("S1/Energy", fontsize=15)
ax0.set_title("Light Yield vs Electric Field Comparision",fontsize=15)
b151_inds = np.in1d(b1509_151[2],b1509_150[2])
b150_inds = np.in1d(b1509_150[2],b1509_151[2])
ax1.plot(b1509_151[2][b151_inds],b1509_151[0][b151_inds]-b1509_150[0][b150_inds],"ko",lw=2,label="201509")
b151_inds = np.in1d(b1409_151[2],b1409_150[2])
b150_inds = np.in1d(b1409_150[2],b1409_151[2])
ax1.plot(b1409_151[2][b151_inds],b1409_151[0][b151_inds]-b1409_150[0][b150_inds],"ro",lw=2,label="201502")
ax1.set_xlim(0,70000)
ax1.set_ylim(-0.25,0.5)
ax1.set_ylabel("(S1/Energy)_Sim - (S1/Energy)_Exp", fontsize=15)
ax1.legend(loc=4,fontsize=15)
ax1.set_xlabel("E field (V/m)", fontsize=15)

# %%
#comparision plot 
plt.figure(12)
fig, (ax0, ax1) = plt.subplots(nrows=2)
ax0.errorbar(b1509_10[2],b1509_10[0],b1509_10[1],lw=2, color="k",label="201509 exp")
#ax0.errorbar(b1509_11[2],b1509_11[0],b1509_11[1],lw=2, color="c",label="201509 sim")
ax0.errorbar(b1409_10[2],b1409_10[0],b1409_10[1],lw=2, color="r",label="201502 exp")
#ax0.errorbar(b1409_11[2],b1409_11[0],b1409_11[1],lw=2, color="b",label="201409 sim")
ax0.legend(loc=4,fontsize=15)
ax0.set_xlim(1.0,2.1)
ax0.set_ylim(3.2,4.)
#ax0.xlabel("Log10 S1", fontsize=18)
ax0.set_ylabel("Log10 S2", fontsize=15)
ax0.set_title("Tritium Band Comparision",fontsize=15)
b510_inds = np.in1d(b1509_10[2],b1409_10[2])
b410_inds = np.in1d(b1409_10[2],b1509_10[2])
ax1.plot(b1509_10[2][b510_inds],b1509_10[0][b510_inds]-b1409_10[0][b410_inds],"ko",lw=2,label="201509")
#b11_inds = np.in1d(b1409_11[2],b1409_10[2])
#b10_inds = np.in1d(b1409_10[2],b1409_11[2])
#ax1.plot(b1409_11[2][b11_inds],b1409_11[0][b11_inds]-b1409_10[0][b10_inds],"ro",lw=2,label="201409")
ax1.set_xlim(1.0,2.1)
ax1.set_ylim(-0.05,0.05)
ax1.set_ylabel("Log10 S2_(2015) - Log10 S2_(2014)", fontsize=15)
ax1.legend(loc=4,fontsize=15)
ax1.set_xlabel("Log10 S1", fontsize=15)
